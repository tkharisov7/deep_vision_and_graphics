# %% [markdown]
# # Compact Convolutional Transformers
#
# This week we try to train Vision Transformer-like network for cifar10 images classification.
#
# This task is based on paper [Escaping the Big Data Paradigm with Compact Transformers](https://arxiv.org/pdf/2104.05704.pdf)

# %% [markdown]
# ## CIFAR dataset
#
# Dataset description:
#
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="imgs/cifar10.jpg" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py

# %%
# !pip3 install numpy
# !pip3 install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.10/site-packages (2.2.6)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 10.1 MB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.8.0
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 19.5 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 KB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0

# %%
#!L
import numpy as np
import random
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 25.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Downloading pillow-12.0.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 62.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 79.8 MB/s eta 0:00:00ta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 91.8 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 73.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in /home/ubuntu/.local/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 KB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pillow-12.0.0 pyparsing-3.2.5

# %%
#!L
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(np.transpose(X_train[i],[1,2,0]))
    plt.title(class_names[y_train[i]])

# %% [markdown]
# ## Prepare dataset and loss
#
# The following code is based on homework 1-pt1 and should be familiar to you.

# %%
# !pip3 install torch
# !pip3 install torchvision
# !pip3 install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 3.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvshmem-cu12==3.3.20
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 18.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.9.90
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 33.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.5.8.93
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 8.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch) (4.15.0)
# Collecting nvidia-nvtx-cu12==12.8.90
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 KB 28.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.3.3.83
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 12.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.8.90
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 KB 102.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 103.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch) (3.6.0)
# Collecting nvidia-nvjitlink-cu12==12.8.93
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 47.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.27.5
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 8.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.7.3.90
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 8.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.10.2.21
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufile-cu12==1.13.1.3
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 99.2 MB/s eta 0:00:00
# Collecting sympy>=1.13.3
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 112.5 MB/s eta 0:00:0000:01
# Collecting nvidia-cublas-cu12==12.8.4.1
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.7.1
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 8.8 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.5.0
#   Downloading triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 8.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 21.9 MB/s eta 0:00:0000:0100:01
# Collecting networkx>=2.5.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 74.0 MB/s eta 0:00:00
# Collecting fsspec>=0.8.5
#   Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 KB 52.3 MB/s eta 0:00:00
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 85.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, fsspec, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
# Successfully installed fsspec-2025.9.0 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 sympy-1.14.0 torch-2.9.0 triton-3.5.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchvision
#   Downloading torchvision-0.24.0-cp310-cp310-manylinux_2_28_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 21.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: torch==2.9.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torchvision) (2.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (4.15.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (10.3.9.90)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (2.27.5)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (1.13.1.3)
# Requirement already satisfied: networkx>=2.5.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.4.2)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (11.7.3.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.9.0->torchvision) (3.0.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.90)
# Requirement already satisfied: triton==3.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.5.0)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (0.7.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.4.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (1.14.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.5.8.93)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (2025.9.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (9.10.2.21)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (12.8.93)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (11.3.3.83)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ubuntu/.local/lib/python3.10/site-packages (from torch==2.9.0->torchvision) (3.3.20)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch==2.9.0->torchvision) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch==2.9.0->torchvision) (1.3.0)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.24.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 3.2 MB/s eta 0:00:00
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
#!L
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import tqdm

# %%
#!L
def get_computing_device():
    if torch.cuda.is_available():
        device = torch.device('cuda:0')
    else:
        device = torch.device('cpu')
    return device

device = get_computing_device()
print(f"Our main computing device is '{device}'")
# Out:
# Our main computing device is 'cuda:0'

# %%
#!L
def compute_loss(logits, y_batch):
    return F.cross_entropy(logits, y_batch).mean().cpu()

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2470, 0.2435, 0.2616))

transform_augment = transforms.Compose([
    transforms.RandomResizedCrop((32,32), scale=(0.9, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomRotation([-5, 5]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
    transforms.Normalize(means, stds),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

train_batch_gen = torch.utils.data.DataLoader(train_loader, 
                                              batch_size=50,
                                              shuffle=True,
                                              num_workers=16)
val_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)

val_batch_gen = torch.utils.data.DataLoader(val_loader, 
                                              batch_size=50,
                                              shuffle=False,
                                              num_workers=16)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# ## Task 1. Multi-head attention
#
# Your turn!

# %% [markdown]
# <img src="imgs/mha_img_original.png" style="width:50%">

# %% [markdown]
# Let's implement MultiHeadAttention for beggining. It's already implemented in pytorch, so we will use `nn.MultiHeadAttention` for testing of your implementation.
#
# As a reminder, (one-head) attention implements a simple formula: $\text{Attention}(Q,K,V) = \text{softmax}(\frac{QK^T}{\sqrt{d_k}})V$, where $d_k$ is size of K

# %%
class CustomMultiHeadSelfAttention(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout=0.0):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        assert embed_dim % num_heads == 0, "embed_dim must be divisible by num_heads"

        self.in_proj = nn.Linear(embed_dim, 3*embed_dim)  # don't change the name
        self.out_proj = nn.Linear(embed_dim, embed_dim)  # don't change the name
        
        self.norm_coeff = self.head_dim ** 0.5
        
        self.attention_dropout = nn.Dropout(dropout)
        
    def forward(self, qkv):
        """
        qkv - query, key and value - it should be the same tensor since we implement self-attention
        """
        # 1. apply self.in_proj to qkv
        qkv = self.in_proj(qkv)
        # 2. split the result of step 1 on three equal parts of size self.embed_dim: query, key, value
        q = qkv[:, :, 0:self.embed_dim]
        k = qkv[:, :, self.embed_dim:self.embed_dim * 2]
        v = qkv[:, :, self.embed_dim * 2:self.embed_dim * 3]
        # 3. compute scaled dot-product attention for different heads in loop. 
        #    i-th head will work on query[:, :, i*head_dim: (i+1)*head_dim], 
        #       key[:, :, i*head_dim: (i+1)*head_dim] and value[:, :, i*head_dim: (i+1)*head_dim]
        #    important: apply dropout to attention maps _after_ softmax, but _before_ multiplication by values.
        #    it follows original implementation and corresponds to dropping out tokens.
        heads = [self._attention(q[:, :, i*self.head_dim: (i+1)*self.head_dim], 
                                k[:, :, i*self.head_dim: (i+1)*self.head_dim], 
                                v[:, :, i*self.head_dim: (i+1)*self.head_dim]) for i in range(self.num_heads)]
        
        # 4. concat all results
        heads = torch.concat(heads, dim=-1)
        # 5. apply self.out_proj to the result of step 5
        result = self.out_proj(heads)

        return result

    def _attention(self, q, k, v):
        return self.attention_dropout(torch.softmax(q @ k.transpose(-2, -1) / self.norm_coeff, dim=-1)) @ v

# %% [markdown]
# Let's check that your implementation works like `torch.nn.MultiheadAttention`

# %%
mha = torch.nn.MultiheadAttention(embed_dim=128, num_heads=16, batch_first=True)

# %%
custom_mha = CustomMultiHeadSelfAttention(embed_dim=128, num_heads=16)
custom_mha.in_proj.weight = mha.in_proj_weight
custom_mha.in_proj.bias = mha.in_proj_bias
custom_mha.out_proj.weight = mha.out_proj.weight
custom_mha.out_proj.bias = mha.out_proj.bias

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

for _ in range(100):
    a = torch.rand((1, 10, 128))
    out1 = mha(a, a, a)[0].cpu().detach().numpy()
    out2 = custom_mha(a).cpu().detach().numpy()
    assert np.allclose(out1, out2, atol=1e-6), f"{out1} {out2}"
    
print ("Congratulations! It works!")
# Out:
# Congratulations! It works!

# %% [markdown]
# ## Task 2: Step-wise learning rate with warm-up
#
# Your task is to implement class that works as `torch.optim.lr_scheduler.StepLR` but supports warm-up.
#
# First of all, examine the docstring and implementation of `StepLR` scheduler:

# %%
torch.optim.lr_scheduler.StepLR??
# Out:
# Init signature:
# torch.optim.lr_scheduler.StepLR(
#     optimizer: 'Optimizer',
#     step_size: 'int',
#     gamma: 'float' = 0.1,
#     last_epoch: 'int' = -1,
# ) -> 'None'
# Source:
# class StepLR(LRScheduler):
#     """Decays the learning rate of each parameter group by gamma every step_size epochs.
#
#     Notice that such decay can happen simultaneously with other changes to the learning rate
#     from outside this scheduler. When last_epoch=-1, sets initial lr as lr.
#
#     Args:
#         optimizer (Optimizer): Wrapped optimizer.
#         step_size (int): Period of learning rate decay.
#         gamma (float): Multiplicative factor of learning rate decay.
#             Default: 0.1.
#         last_epoch (int): The index of last epoch. Default: -1.
#
#     Example:
#         >>> # xdoctest: +SKIP
#         >>> # Assuming optimizer uses lr = 0.05 for all groups
#         >>> # lr = 0.05     if epoch < 30
#         >>> # lr = 0.005    if 30 <= epoch < 60
#         >>> # lr = 0.0005   if 60 <= epoch < 90
#         >>> # ...
#         >>> scheduler = StepLR(optimizer, step_size=30, gamma=0.1)
#         >>> for epoch in range(100):
#         >>>     train(...)
#         >>>     validate(...)
#         >>>     scheduler.step()
#
#     .. image:: ../scripts/lr_scheduler_images/StepLR.png
#     """
#
#     def __init__(
#         self,
#         optimizer: Optimizer,
#         step_size: int,
#         gamma: float = 0.1,
#         last_epoch: int = -1,
#     ) -> None:  # noqa: D107
#         self.step_size = step_size
#         self.gamma = gamma
#         super().__init__(optimizer, last_epoch)
#
#     @override
#     def get_lr(self) -> list[float]:
#         """Compute the learning rate of each parameter group."""
#         _warn_get_lr_called_within_step(self)
#
#         if (self.last_epoch == 0) or (self.last_epoch % self.step_size != 0):
#             return [group["lr"] for group in self.optimizer.param_groups]
#         return [group["lr"] * self.gamma for group in self.optimizer.param_groups]
#
#     def _get_closed_form_lr(self) -> list[float]:
#         return [
#             base_lr * self.gamma ** (self.last_epoch // self.step_size)
#             for base_lr in self.base_lrs
#         ]
# File:           ~/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py
# Type:           type
# Subclasses:

# %% [markdown]
# Then implement `get_lr()` method. It should work as following:
# 1. If `self.last_epoch` is in `[0, self.warmup_epochs]`, scheduler is in warm-up mode and learning rates for each parameter group should lineary increase during epochs from `self.warmup_lr_init` to `self.base_lrs` (which are the original learning rates)
#
# 2. Else if `self.last_epoch - self.warmup_epochs` is not divisible by `self.step_size`, return the previous learning rates which are available through `[group['lr'] for group in self.optimizer.param_groups]`
#
# 3. Else if `self.last_epoch - self.warmup_epochs` is divisible by `self.step_size` and current learning rates multiplied by `self.gamma` are not less then `self.min_lr`, then multiply them and return new values.
#
# 4. Otherwise return the last learning rates.

# %%
class StepLRWithWarmup(torch.optim.lr_scheduler.LRScheduler):
    def __init__(self, optimizer, step_size, gamma=0.1, warmup_epochs=3, warmup_lr_init=1e-5, 
                 min_lr=1e-5,
                 last_epoch=-1, verbose=False):
        self.step_size = step_size
        self.gamma = gamma
        self.warmup_epochs = warmup_epochs
        self.warmup_lr_init = warmup_lr_init
        self.min_lr = min_lr
        
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        if not self._get_lr_called_within_step:
            warnings.warn("To get the last learning rate computed by the scheduler, "
                          "please use `get_last_lr()`.", UserWarning)
            
        if (0 <= self.last_epoch  <= self.warmup_epochs):
            return [(base_lr - self.warmup_lr_init) * self.last_epoch / self.warmup_epochs + self.warmup_lr_init
                     for base_lr in self.base_lrs]
        elif (self.last_epoch - self.warmup_epochs > 0 and ((self.last_epoch - self.warmup_epochs) % self.step_size == 0)):
            return [group['lr'] * self.gamma if group['lr'] * self.gamma >= self.min_lr else group['lr'] 
                    for group in self.optimizer.param_groups]
        else:
            return [group['lr'] for group in self.optimizer.param_groups]

# %% [markdown]
# Let's check what you have written.

# %%
WARMUP_LR_INIT = 1e-5
WARMUP_EPOCHS = 10
STEP_SIZE = 10
GAMMA = 0.1
MIN_LR = 1e-5
OPT_LR = 1e-3

dummy_net = nn.Sequential(nn.Linear(10,10))
dummy_opt = torch.optim.Adam(dummy_net.parameters(), lr=OPT_LR)

scheduler = StepLRWithWarmup(optimizer=dummy_opt, step_size=STEP_SIZE, gamma=GAMMA, 
                                      warmup_epochs=WARMUP_EPOCHS, warmup_lr_init=WARMUP_LR_INIT,
                                      min_lr=MIN_LR)

# we need to do at least one optimizer step before calling scheduler.step()
# in order to make pytorch happy
dummy_opt.step()  


learning_rates = []
for i in range(100):
    learning_rates.append(scheduler.get_last_lr())
    scheduler.step()
    
plt.plot(learning_rates)
plt.grid()
plt.title('Learning rates')
    
assert np.isclose(learning_rates[0], WARMUP_LR_INIT), \
    f"LR on the first epoch should be equal to {WARMUP_LR_INIT}, actual value {learning_rates[0]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS], OPT_LR), \
    f"LR after warmup shold be equal to {OPT_LR}, actual value {learning_rates[WARMUP_EPOCHS]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE-1], OPT_LR), \
    f"LR after warmup + (STEP_SIZE-1) steps should be equal to {OPT_LR}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE], OPT_LR*GAMMA), \
    f"LR after warmup + (STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1], OPT_LR*GAMMA), \
    f"LR after warmup + (2*STEP_SIZE-1) steps should be equal to {OPT_LR*GAMMA}, "\
    f"actual value {learning_rates[WARMUP_EPOCHS+STEP_SIZE*2-1]}"
assert np.isclose(learning_rates[WARMUP_EPOCHS+2*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (2*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+2*STEP_SIZE]}"

assert np.isclose(learning_rates[WARMUP_EPOCHS+3*STEP_SIZE], OPT_LR*GAMMA**2), \
    f"LR after warmup + (3*STEP_SIZE) steps shold be equal to {OPT_LR*GAMMA**2}, " \
    f"actual value {learning_rates[WARMUP_EPOCHS+3*STEP_SIZE]}"

for i in range(WARMUP_EPOCHS):
    expected_val = WARMUP_LR_INIT + i*(OPT_LR-WARMUP_LR_INIT) / WARMUP_EPOCHS
    actual_val = learning_rates[i]
    assert np.isclose(actual_val, expected_val), \
        f"LR should linary increase from {WARMUP_LR_INIT} to {OPT_LR} during warmup."\
        f"Expected: {expected_val}, actual: {actual_val}, iteration={i}"
assert all(elem[0] >= MIN_LR for elem in learning_rates)
print("All asserts were passed!")
# Out:
# All asserts were passed!

# %% [markdown]
# ## Task 3. Compact Convolutional Transformer
#
# During seminar you learned the main components of vision transformer: Tokenizer, Transformer encoder, position embeddings. At this point, it's expected that you have solved the ipython notebook from the seminar. If you didn't, then you know what to do before starting the current task)

# %% [markdown]
# Your task is to implement Compact Convolutional Transformer (CCT). It has two main changes comparing to the original ViT that was implemented during seminar. The first one is in tokenizer. Authors of CCT suggested to apply the first convolution with stride=1 allowing transformer to work with input patches that overlaps with each other. Since simple removing of stride increases the spatial resolution of the input tensor, we use MaxPool2d with desired stride in order to reduce the number of tokens.

# %%
class TokenizerCCT(nn.Module):
    def __init__(self,
                 kernel_size=3, stride=1, padding=1,
                 pooling_kernel_size=3, pooling_stride=2, pooling_padding=1,
                 n_input_channels=3,
                 n_output_channels=64,
                 ):
        super().__init__()
        self.tokenizer_layers = nn.Sequential(
                # YOUR CODE
                # it should implement the following sequence of layers:
                # Conv2d(n_input_channels, n_output_channels, kernel_size, stride, padding, bias=False) + 
                #   + ReLU + 
                #   + MaxPool(pooling_kernel_size, pooling_stride, pooling_padding)
                nn.Conv2d(n_input_channels, n_output_channels, kernel_size, stride, padding, bias=False),
                nn.ReLU(),
                nn.MaxPool2d(pooling_kernel_size, pooling_stride, pooling_padding))

        self.flattener = nn.Flatten(2, 3)  # flat h,w dims into token dim

    def forward(self, x):
        y = self.tokenizer_layers(x)
        y = self.flattener(y)
        y = y.transpose(-2, -1)  # swap token dim and embedding dim
        return y

# %% [markdown]
# The second change is that CCT uses learnable pooling instead of class token for global features extraction. Its formula is similar to attention formula:
# $$y = \text{softmax}(WX^T+b) * X$$
# where $X$ - layer input - matrix of shape [batch_size, n_tokens, n_embedding], $W$, $b$ - learnable parameters, that transform each token embedding vector to 1 element (in fact it's just a linear layer with output_dim=1).

# %%
class SeqPooling(nn.Module):
    def __init__(self, embedding_dim):
        super().__init__()
        self.attention_pool = nn.Linear(embedding_dim, 1)
          
    def forward(self, x):
        # YOUR CODE
        # 1. apply self.attention_pool to x
        w = self.attention_pool(x)
        # 2. take softmax over the first dim (token dim)
        w = F.softmax(w, dim=1)
        # 3. transpose two last dims of w to make its shape be equal to [N, 1, n_tokens]
        w = w.transpose(-2, -1)
        
        # 4. call torch.matmul from 'w' and input tensor 'x'
        y = w @ x
        
        # 5. now 'y' shape is [N, 1, embedding_dim]. Squeeze the second dim
        y = y.squeeze(1)
        
        return y

# %% [markdown]
# The following three modules were implemented by you during seminar, so you can just copy-paste their implementations.

# %%
def create_mlp(embedding_dim, mlp_size, dropout_rate):
    return nn.Sequential(
        # YOUR CODE: Linear + GELU + Dropout + Linear + Dropout
        nn.Linear(embedding_dim, mlp_size),
        nn.GELU(),
        nn.Dropout(dropout_rate),
        nn.Linear(mlp_size, embedding_dim),
        nn.Dropout(dropout_rate),
    )

# %%
class DropPath(nn.Module):
    def __init__(self, drop_prob=None):
        super(DropPath, self).__init__()
        self.drop_prob = drop_prob

    def forward(self, x):
        if self.drop_prob == 0. or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)  # work with diff dim tensors, not just 2D ConvNets
        # YOUR CODE: 
        # generate random tensor, binarize it, cast to x.dtype, multiply x by the mask, divide the result on keep_prob
        random_tensor = (torch.rand(shape, device=x.device) < keep_prob).to(x.dtype)
        output = x * random_tensor / keep_prob
        return output

# it is also highly recommended to write some simple test to ensure,
# that this layer indeed nullifies input with probability `drop_prob`

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, embedding_dim, num_heads, mlp_size, dropout=0.1, attention_dropout=0.1,
                 drop_path_rate=0.1):
        super().__init__()
        # YOUR CODE
        self.attention_pre_norm = nn.LayerNorm(embedding_dim)
        self.attention = torch.nn.MultiheadAttention(embedding_dim, num_heads, attention_dropout, batch_first=True)       # Do not forget to set `batch_first` parameter
        self.attention_output_dropout = nn.Dropout(dropout)

        self.mlp_pre_norm = nn.LayerNorm(embedding_dim)
        self.mlp = create_mlp(embedding_dim, mlp_size, dropout)
        self.drop_path = DropPath(drop_path_rate) if drop_path_rate > 0 else nn.Identity()

    def forward(self, x):
        # first block
        y = self.attention_pre_norm(x)
        attention = self.attention(y, y, y)[0]
        attention = self.attention_output_dropout(attention)
        x = x + self.drop_path(attention)   # Residual connection
            
        # second block
        y = self.mlp_pre_norm(x)
        y = self.mlp(y)
        x = x + self.drop_path(y)  # Residual connection
        return x

# %% [markdown]
# The final class for the CCT. It looks the same as `VisionTransformer` class in seminar notebook, except the custom tokenizer and pooling. Here we implement a simple version of CCT, whose Tokenizer consist of one convolution of 3x3.

# %%
class CompactConvTransformer3x1(nn.Module):
    def __init__(self,
                 input_height, input_width,
                 n_tokens,
                 n_input_channels,
                 embedding_dim,
                 num_layers,
                 num_heads=4,
                 num_classes=10,
                 mlp_ratio=2,
                 dropout=0.1,
                 attention_dropout=0.1,
                 stochastic_depth=0.1):
        super().__init__()
        
        # 1. Tokenizer
        pooling_stride = 2
        self.tokenizer = TokenizerCCT(kernel_size=3, stride=1, padding=1, 
                                      pooling_kernel_size=3, pooling_stride=pooling_stride, pooling_padding=1,
                                      n_output_channels=embedding_dim)
        n_tokens = input_height // pooling_stride
        
        # 2. Positional embeddings
        self.positional_embeddings = torch.nn.Parameter(
            torch.empty((1, n_tokens*n_tokens, embedding_dim)), requires_grad=True)
        torch.nn.init.trunc_normal_(self.positional_embeddings, std=0.2)
        
        # 3. TransformerEncoder with DropPath
        mlp_size = int(embedding_dim * mlp_ratio)
        layers_drop_path_rate = [x.item() for x in torch.linspace(0, stochastic_depth, num_layers)]
        self.blocks = nn.Sequential(*[
            TransformerEncoder(
                embedding_dim, num_heads, mlp_size, 
                dropout=dropout, attention_dropout=attention_dropout,
                drop_path_rate=layers_drop_path_rate[i]) 
            for i in range(num_layers)])
        
        # 4. normalization before pooling
        self.norm = nn.LayerNorm(embedding_dim)
        
        # 5. sequence pooling
        self.pool = SeqPooling(embedding_dim)

        # 6. layer for the final prediction
        self.fc = nn.Linear(embedding_dim, num_classes)
        
    def forward(self, x):
        # YOUR CODE
        # 1. apply tokenizer to x
        patch_embeddings = self.tokenizer(x)
        
        # 2. add position embeddings
        x = patch_embeddings + self.positional_embeddings

        # 3. apply transformer encoder blocks
        for block in self.blocks:
            x = block(x)
            
        # 4. apply self.norm
        x = self.norm(x)
        
        # 5. apply sequence pooling
        x = self.pool(x)
        
        # 6. final prediction
        x = self.fc(x)
        return x

# %% [markdown]
# ## Final training
#
# If everything was implemented correctly, the following code will give you a model with > 85.5% accuracy (in fact it should be ~87.5%). If you see a smaller number, check your implementation of modules above.

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

model = CompactConvTransformer3x1(input_height=32, input_width=32, n_tokens=16, n_input_channels=3, 
                                  embedding_dim=128, num_layers=4, num_heads=4, num_classes=10, mlp_ratio=2)
model = model.to(device)
opt = torch.optim.Adam(model.parameters(), weight_decay=1e-4)
scheduler = StepLRWithWarmup(opt, 40, gamma=0.3, warmup_epochs=10)

# %%
import time
num_epochs = 120 # total amount of full passes over training data

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    train_loss = []
    val_accuracy = []
    
    for X_batch, y_batch in train_batch_gen:
        opt.zero_grad()
        # train on batch
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        logits = model(X_batch)
        loss = compute_loss(logits, y_batch)
        loss.backward()
        opt.step()
        train_loss.append(loss.data.numpy())
    print(scheduler.get_last_lr())
    scheduler.step()
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in val_batch_gen:
        X_batch = X_batch.to(device)
        y_batch = y_batch.numpy()
        logits = model(X_batch).cpu()
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss)))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy) * 100))
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# [1e-05]
# Epoch 1 of 120 took 43.790s
#   training loss (in-iteration): 	2.076958
#   validation accuracy: 			32.39 %
# [0.00010899999999999999]
# Epoch 2 of 120 took 43.295s
#   training loss (in-iteration): 	1.714281
#   validation accuracy: 			46.83 %
# [0.000208]
# Epoch 3 of 120 took 43.473s
#   training loss (in-iteration): 	1.481967
#   validation accuracy: 			55.25 %
# [0.00030700000000000004]
# Epoch 4 of 120 took 43.591s
#   training loss (in-iteration): 	1.322347
#   validation accuracy: 			58.16 %
# [0.000406]
# Epoch 5 of 120 took 43.660s
#   training loss (in-iteration): 	1.227876
#   validation accuracy: 			64.02 %
# [0.000505]
# Epoch 6 of 120 took 43.610s
#   training loss (in-iteration): 	1.149514
#   validation accuracy: 			62.15 %
# [0.000604]
# Epoch 7 of 120 took 43.574s
#   training loss (in-iteration): 	1.094731
#   validation accuracy: 			64.18 %
# [0.0007030000000000001]
# Epoch 8 of 120 took 43.592s
#   training loss (in-iteration): 	1.042828
#   validation accuracy: 			67.85 %
# [0.000802]
# Epoch 9 of 120 took 44.074s
#   training loss (in-iteration): 	1.006344
#   validation accuracy: 			68.54 %
# [0.000901]
# Epoch 10 of 120 took 43.477s
#   training loss (in-iteration): 	0.981017
#   validation accuracy: 			68.50 %
# [0.001]
# Epoch 11 of 120 took 43.443s
#   training loss (in-iteration): 	0.958305
#   validation accuracy: 			68.13 %
# [0.001]
# Epoch 12 of 120 took 43.506s
#   training loss (in-iteration): 	0.926609
#   validation accuracy: 			68.71 %
# [0.001]
# Epoch 13 of 120 took 43.459s
#   training loss (in-iteration): 	0.893342
#   validation accuracy: 			72.47 %
# [0.001]
# Epoch 14 of 120 took 43.795s
#   training loss (in-iteration): 	0.861278
#   validation accuracy: 			70.26 %
# [0.001]
# Epoch 15 of 120 took 43.994s
#   training loss (in-iteration): 	0.840405
#   validation accuracy: 			72.34 %
# [0.001]
# Epoch 16 of 120 took 44.212s
#   training loss (in-iteration): 	0.823845
#   validation accuracy: 			74.33 %
# [0.001]
# Epoch 17 of 120 took 43.713s
#   training loss (in-iteration): 	0.799330
#   validation accuracy: 			75.57 %
# [0.001]
# Epoch 18 of 120 took 43.954s
#   training loss (in-iteration): 	0.780335
#   validation accuracy: 			75.04 %
# [0.001]
# Epoch 19 of 120 took 43.786s
#   training loss (in-iteration): 	0.759703
#   validation accuracy: 			73.64 %
# [0.001]
# Epoch 20 of 120 took 43.859s
#   training loss (in-iteration): 	0.741516
#   validation accuracy: 			76.93 %
# [0.001]
# Epoch 21 of 120 took 43.785s
#   training loss (in-iteration): 	0.734412
#   validation accuracy: 			77.04 %
# [0.001]
# Epoch 22 of 120 took 43.821s
#   training loss (in-iteration): 	0.719693
#   validation accuracy: 			75.39 %
# [0.001]
# Epoch 23 of 120 took 43.609s
#   training loss (in-iteration): 	0.704586
#   validation accuracy: 			77.46 %
# [0.001]
# Epoch 24 of 120 took 43.541s
#   training loss (in-iteration): 	0.696428
#   validation accuracy: 			77.36 %
# [0.001]
# Epoch 25 of 120 took 43.631s
#   training loss (in-iteration): 	0.685300
#   validation accuracy: 			79.41 %
# [0.001]
# Epoch 26 of 120 took 43.410s
#   training loss (in-iteration): 	0.678916
#   validation accuracy: 			77.69 %
# [0.001]
# Epoch 27 of 120 took 43.391s
#   training loss (in-iteration): 	0.666737
#   validation accuracy: 			78.03 %
# [0.001]
# Epoch 28 of 120 took 43.526s
#   training loss (in-iteration): 	0.653974
#   validation accuracy: 			78.31 %
# [0.001]
# Epoch 29 of 120 took 43.306s
#   training loss (in-iteration): 	0.644692
#   validation accuracy: 			77.32 %
# [0.001]
# Epoch 30 of 120 took 43.483s
#   training loss (in-iteration): 	0.640684
#   validation accuracy: 			79.80 %
# [0.001]
# Epoch 31 of 120 took 43.471s
#   training loss (in-iteration): 	0.635159
#   validation accuracy: 			79.16 %
# [0.001]
# Epoch 32 of 120 took 43.715s
#   training loss (in-iteration): 	0.625193
#   validation accuracy: 			79.15 %
# [0.001]
# Epoch 33 of 120 took 43.526s
#   training loss (in-iteration): 	0.614661
#   validation accuracy: 			79.24 %
# [0.001]
# Epoch 34 of 120 took 43.711s
#   training loss (in-iteration): 	0.615252
#   validation accuracy: 			79.77 %
# [0.001]
# Epoch 35 of 120 took 44.115s
#   training loss (in-iteration): 	0.609807
#   validation accuracy: 			78.61 %
# [0.001]
# Epoch 36 of 120 took 44.068s
#   training loss (in-iteration): 	0.600024
#   validation accuracy: 			79.43 %
# [0.001]
# Epoch 37 of 120 took 43.999s
#   training loss (in-iteration): 	0.595283
#   validation accuracy: 			80.94 %
# [0.001]
# Epoch 38 of 120 took 43.799s
#   training loss (in-iteration): 	0.591990
#   validation accuracy: 			81.18 %
# [0.001]
# Epoch 39 of 120 took 43.896s
#   training loss (in-iteration): 	0.586555
#   validation accuracy: 			80.88 %
# [0.001]
# Epoch 40 of 120 took 44.094s
#   training loss (in-iteration): 	0.582267
#   validation accuracy: 			81.26 %
# [0.001]
# Epoch 41 of 120 took 43.866s
#   training loss (in-iteration): 	0.576108
#   validation accuracy: 			82.32 %
# [0.001]
# Epoch 42 of 120 took 44.025s
#   training loss (in-iteration): 	0.568363
#   validation accuracy: 			81.66 %
# [0.001]
# Epoch 43 of 120 took 43.904s
#   training loss (in-iteration): 	0.563921
#   validation accuracy: 			82.00 %
# [0.001]
# Epoch 44 of 120 took 43.853s
#   training loss (in-iteration): 	0.559825
#   validation accuracy: 			81.19 %
# [0.001]
# Epoch 45 of 120 took 43.656s
#   training loss (in-iteration): 	0.555693
#   validation accuracy: 			81.15 %
# [0.001]
# Epoch 46 of 120 took 43.703s
#   training loss (in-iteration): 	0.556041
#   validation accuracy: 			82.39 %
# [0.001]
# Epoch 47 of 120 took 43.626s
#   training loss (in-iteration): 	0.548395
#   validation accuracy: 			80.69 %
# [0.001]
# Epoch 48 of 120 took 43.942s
#   training loss (in-iteration): 	0.548915
#   validation accuracy: 			82.88 %
# [0.001]
# Epoch 49 of 120 took 43.608s
#   training loss (in-iteration): 	0.544018
#   validation accuracy: 			82.34 %
# [0.001]
# Epoch 50 of 120 took 43.578s
#   training loss (in-iteration): 	0.539882
#   validation accuracy: 			81.83 %
# [0.0003]
# Epoch 51 of 120 took 43.659s
#   training loss (in-iteration): 	0.433361
#   validation accuracy: 			84.32 %
# [0.0003]
# Epoch 52 of 120 took 43.587s
#   training loss (in-iteration): 	0.415067
#   validation accuracy: 			84.58 %
# [0.0003]
# Epoch 53 of 120 took 43.642s
#   training loss (in-iteration): 	0.399581
#   validation accuracy: 			85.02 %
# [0.0003]
# Epoch 54 of 120 took 43.498s
#   training loss (in-iteration): 	0.398362
#   validation accuracy: 			84.85 %
# [0.0003]
# Epoch 55 of 120 took 43.900s
#   training loss (in-iteration): 	0.386434
#   validation accuracy: 			84.63 %
# [0.0003]
# Epoch 56 of 120 took 44.086s
#   training loss (in-iteration): 	0.383048
#   validation accuracy: 			84.72 %
# [0.0003]
# Epoch 57 of 120 took 44.583s
#   training loss (in-iteration): 	0.374712
#   validation accuracy: 			84.86 %
# [0.0003]
# Epoch 58 of 120 took 44.106s
#   training loss (in-iteration): 	0.378714
#   validation accuracy: 			84.91 %
# [0.0003]
# Epoch 59 of 120 took 44.118s
#   training loss (in-iteration): 	0.369744
#   validation accuracy: 			84.82 %
# [0.0003]
# Epoch 60 of 120 took 44.073s
#   training loss (in-iteration): 	0.367122
#   validation accuracy: 			85.25 %
# [0.0003]
# Epoch 61 of 120 took 43.847s
#   training loss (in-iteration): 	0.367570
#   validation accuracy: 			84.92 %
# [0.0003]
# Epoch 62 of 120 took 43.906s
#   training loss (in-iteration): 	0.364223
#   validation accuracy: 			84.56 %
# [0.0003]
# Epoch 63 of 120 took 44.027s
#   training loss (in-iteration): 	0.356359
#   validation accuracy: 			85.02 %
# [0.0003]
# Epoch 64 of 120 took 44.150s
#   training loss (in-iteration): 	0.357212
#   validation accuracy: 			84.39 %
# [0.0003]
# Epoch 65 of 120 took 43.971s
#   training loss (in-iteration): 	0.352351
#   validation accuracy: 			85.24 %
# [0.0003]
# Epoch 66 of 120 took 43.789s
#   training loss (in-iteration): 	0.350975
#   validation accuracy: 			85.40 %
# [0.0003]
# Epoch 67 of 120 took 43.556s
#   training loss (in-iteration): 	0.346148
#   validation accuracy: 			85.05 %
# [0.0003]
# Epoch 68 of 120 took 43.611s
#   training loss (in-iteration): 	0.347173
#   validation accuracy: 			85.28 %
# [0.0003]
# Epoch 69 of 120 took 43.669s
#   training loss (in-iteration): 	0.341734
#   validation accuracy: 			85.05 %
# [0.0003]
# Epoch 70 of 120 took 43.632s
#   training loss (in-iteration): 	0.339415
#   validation accuracy: 			85.31 %
# [0.0003]
# Epoch 71 of 120 took 43.436s
#   training loss (in-iteration): 	0.343090
#   validation accuracy: 			85.07 %
# [0.0003]
# Epoch 72 of 120 took 43.498s
#   training loss (in-iteration): 	0.338789
#   validation accuracy: 			85.43 %
# [0.0003]
# Epoch 73 of 120 took 43.649s
#   training loss (in-iteration): 	0.335682
#   validation accuracy: 			85.75 %
# [0.0003]
# Epoch 74 of 120 took 43.446s
#   training loss (in-iteration): 	0.334996
#   validation accuracy: 			84.89 %
# [0.0003]
# Epoch 75 of 120 took 43.725s
#   training loss (in-iteration): 	0.332703
#   validation accuracy: 			85.58 %
# [0.0003]
# Epoch 76 of 120 took 44.321s
#   training loss (in-iteration): 	0.328649
#   validation accuracy: 			85.13 %
# [0.0003]
# Epoch 77 of 120 took 44.335s
#   training loss (in-iteration): 	0.328441
#   validation accuracy: 			85.49 %
# [0.0003]
# Epoch 78 of 120 took 44.273s
#   training loss (in-iteration): 	0.326434
#   validation accuracy: 			85.35 %
# [0.0003]
# Epoch 79 of 120 took 44.108s
#   training loss (in-iteration): 	0.321347
#   validation accuracy: 			85.78 %
# [0.0003]
# Epoch 80 of 120 took 44.179s
#   training loss (in-iteration): 	0.328798
#   validation accuracy: 			85.11 %
# [0.0003]
# Epoch 81 of 120 took 43.969s
#   training loss (in-iteration): 	0.321991
#   validation accuracy: 			85.34 %
# [0.0003]
# Epoch 82 of 120 took 44.098s
#   training loss (in-iteration): 	0.318551
#   validation accuracy: 			85.29 %
# [0.0003]
# Epoch 83 of 120 took 43.878s
#   training loss (in-iteration): 	0.322135
#   validation accuracy: 			84.96 %
# [0.0003]
# Epoch 84 of 120 took 44.672s
#   training loss (in-iteration): 	0.316737
#   validation accuracy: 			85.91 %
# [0.0003]
# Epoch 85 of 120 took 43.848s
#   training loss (in-iteration): 	0.313591
#   validation accuracy: 			86.10 %
# [0.0003]
# Epoch 86 of 120 took 43.585s
#   training loss (in-iteration): 	0.311969
#   validation accuracy: 			85.17 %
# [0.0003]
# Epoch 87 of 120 took 43.629s
#   training loss (in-iteration): 	0.312994
#   validation accuracy: 			83.94 %
# [0.0003]
# Epoch 88 of 120 took 43.595s
#   training loss (in-iteration): 	0.308500
#   validation accuracy: 			85.46 %
# [0.0003]
# Epoch 89 of 120 took 43.774s
#   training loss (in-iteration): 	0.307491
#   validation accuracy: 			85.45 %
# [0.0003]
# Epoch 90 of 120 took 43.764s
#   training loss (in-iteration): 	0.303367
#   validation accuracy: 			84.63 %
# [8.999999999999999e-05]
# Epoch 91 of 120 took 43.624s
#   training loss (in-iteration): 	0.261596
#   validation accuracy: 			85.89 %
# [8.999999999999999e-05]
# Epoch 92 of 120 took 43.508s
#   training loss (in-iteration): 	0.250567
#   validation accuracy: 			85.81 %
# [8.999999999999999e-05]
# Epoch 93 of 120 took 43.507s
#   training loss (in-iteration): 	0.247913
#   validation accuracy: 			86.31 %
# [8.999999999999999e-05]
# Epoch 94 of 120 took 43.560s
#   training loss (in-iteration): 	0.244772
#   validation accuracy: 			85.90 %
# [8.999999999999999e-05]
# Epoch 95 of 120 took 43.459s
#   training loss (in-iteration): 	0.240875
#   validation accuracy: 			86.17 %
# [8.999999999999999e-05]
# Epoch 96 of 120 took 44.005s
#   training loss (in-iteration): 	0.240480
#   validation accuracy: 			86.23 %
# [8.999999999999999e-05]
# Epoch 97 of 120 took 43.966s
#   training loss (in-iteration): 	0.238085
#   validation accuracy: 			86.01 %
# [8.999999999999999e-05]
# Epoch 98 of 120 took 44.137s
#   training loss (in-iteration): 	0.234673
#   validation accuracy: 			86.23 %
# [8.999999999999999e-05]
# Epoch 99 of 120 took 43.855s
#   training loss (in-iteration): 	0.235469
#   validation accuracy: 			86.24 %
# [8.999999999999999e-05]
# Epoch 100 of 120 took 44.072s
#   training loss (in-iteration): 	0.232018
#   validation accuracy: 			86.34 %
# [8.999999999999999e-05]
# Epoch 101 of 120 took 44.004s
#   training loss (in-iteration): 	0.232865
#   validation accuracy: 			86.22 %
# [8.999999999999999e-05]
# Epoch 102 of 120 took 44.037s
#   training loss (in-iteration): 	0.230685
#   validation accuracy: 			86.19 %
# [8.999999999999999e-05]
# Epoch 103 of 120 took 43.928s
#   training loss (in-iteration): 	0.229227
#   validation accuracy: 			86.30 %
# [8.999999999999999e-05]
# Epoch 104 of 120 took 44.006s
#   training loss (in-iteration): 	0.227826
#   validation accuracy: 			86.38 %
# [8.999999999999999e-05]
# Epoch 105 of 120 took 43.811s
#   training loss (in-iteration): 	0.228098
#   validation accuracy: 			86.12 %
# [8.999999999999999e-05]
# Epoch 106 of 120 took 43.824s
#   training loss (in-iteration): 	0.228205
#   validation accuracy: 			86.20 %
# [8.999999999999999e-05]
# Epoch 107 of 120 took 43.557s
#   training loss (in-iteration): 	0.229247
#   validation accuracy: 			86.04 %
# [8.999999999999999e-05]
# Epoch 108 of 120 took 43.560s
#   training loss (in-iteration): 	0.222910
#   validation accuracy: 			86.23 %
# [8.999999999999999e-05]
# Epoch 109 of 120 took 43.568s
#   training loss (in-iteration): 	0.225774
#   validation accuracy: 			86.21 %
# [8.999999999999999e-05]
# Epoch 110 of 120 took 43.553s
#   training loss (in-iteration): 	0.226038
#   validation accuracy: 			86.25 %
# [8.999999999999999e-05]
# Epoch 111 of 120 took 43.537s
#   training loss (in-iteration): 	0.223329
#   validation accuracy: 			86.32 %
# [8.999999999999999e-05]
# Epoch 112 of 120 took 43.517s
#   training loss (in-iteration): 	0.219517
#   validation accuracy: 			86.33 %
# [8.999999999999999e-05]
# Epoch 113 of 120 took 43.410s
#   training loss (in-iteration): 	0.219403
#   validation accuracy: 			86.44 %
# [8.999999999999999e-05]
# Epoch 114 of 120 took 43.663s
#   training loss (in-iteration): 	0.217649
#   validation accuracy: 			86.29 %
# [8.999999999999999e-05]
# Epoch 115 of 120 took 43.381s
#   training loss (in-iteration): 	0.218874
#   validation accuracy: 			86.34 %
# [8.999999999999999e-05]
# Epoch 116 of 120 took 43.657s
#   training loss (in-iteration): 	0.218367
#   validation accuracy: 			86.67 %
# [8.999999999999999e-05]
# Epoch 117 of 120 took 44.027s
#   training loss (in-iteration): 	0.219085
#   validation accuracy: 			86.18 %
# [8.999999999999999e-05]
# Epoch 118 of 120 took 44.087s
#   training loss (in-iteration): 	0.217548
#   validation accuracy: 			86.26 %
# [8.999999999999999e-05]
# Epoch 119 of 120 took 44.017s
#   training loss (in-iteration): 	0.214285
#   validation accuracy: 			86.23 %
# [8.999999999999999e-05]
# Epoch 120 of 120 took 44.032s
#   training loss (in-iteration): 	0.214497
#   validation accuracy: 			86.49 %
